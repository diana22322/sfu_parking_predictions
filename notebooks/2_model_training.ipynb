# %%
import sagemaker
import boto3
import pandas as pd
import numpy as np
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost.estimator import XGBoost
from sklearn.model_selection import train_test_split

# CONFIGURATION
role = get_execution_role()
session = sagemaker.Session()
region = boto3.Session().region_name
bucket = "c732-sfu-parking-data-lake" 
prefix = "sagemaker/sfu-parking"

# input path 
training_data_s3 = f"s3://{bucket}/processed/training_features/"

print(f"Region: {region}")
print(f"Role: {role}")
print(f"Reading data from: {training_data_s3}")

# Load data
df = pd.read_parquet(training_data_s3)
print(f"Data Loaded. Shape: {df.shape}")

# drop non-feature columns for training (keep lot_id/campus but encode them)
# One-Hot Encode categorical variables
df_encoded = pd.get_dummies(df, columns=['lot_id', 'campus'])

# Define features (X) and labels (Y)
# drop target columns and identifiers not needed for X
features = df_encoded.drop(['occupancy_plus_15m', 'departures_in_next_15m', 'timestamp', 'date'], axis=1, errors='ignore')

# targets
label_occupancy = df['occupancy_plus_15m']
label_departure = df['departures_in_15m']

# Split Data (80% training, 20% validation)
X_train, X_val, y_occ_train, y_occ_val, y_dep_train, y_dep_val = train_test_split(
    features, label_occupancy, label_departure, test_size=0.2, random_state=42
)

# Model training using XGBOOST 
# XGBoost in SageMaker expects CSV data in S3 with no headers
# first column = target label, remaining columns = features

def upload_to_s3(x, y, name):
    # combine label + features
    dataset = pd.concat([y, x], axis=1)
    filename = f"{name}.csv"
    dataset.to_csv(filename, header=False, index=False)
    
    return session.upload_data(filename, bucket=bucket, key_prefix=f"{prefix}/input/{name}")

# Upload occupancy data
train_occ_uri = upload_to_s3(X_train, y_occ_train, 'train_occupancy')
val_occ_uri = upload_to_s3(X_val, y_occ_val, 'val_occupancy')

# Upload departure data
train_dep_uri = upload_to_s3(X_train, y_dep_train, 'train_departure')
val_dep_uri = upload_to_s3(X_val, y_dep_val, 'val_departure')

print("Data uploaded to S3 for training.")

# Training 2 models
# Retrieve XGBoost container image
xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.5-1")

# Common hyperparameters
hyperparams = {
    "max_depth": "5",
    "eta": "0.2",
    "gamma": "4",
    "min_child_weight": "6",
    "subsample": "0.8",
    "objective": "reg:squarederror",
    "num_round": "100"
}

# Train model A: occupancy predictor 
print("Training Occupancy Model...")
xgb_occ = sagemaker.estimator.Estimator(
    image_uri=xgboost_container,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=f"s3://{bucket}/{prefix}/output/occupancy",
    sagemaker_session=session
)
xgb_occ.set_hyperparameters(**hyperparams)
xgb_occ.fit({'train': TrainingInput(train_occ_uri, content_type='csv'), 
             'validation': TrainingInput(val_occ_uri, content_type='csv')})

# Train model B: departure predictor
print("Training Departure Model...")
xgb_dep = sagemaker.estimator.Estimator(
    image_uri=xgboost_container,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=f"s3://{bucket}/{prefix}/output/departure",
    sagemaker_session=session
)
xgb_dep.set_hyperparameters(**hyperparams)
xgb_dep.fit({'train': TrainingInput(train_dep_uri, content_type='csv'), 
             'validation': TrainingInput(val_dep_uri, content_type='csv')})

# Deploy endpoints
print("Deploying Endpoints...")

# Deploy occupancy model
predictor_occ = xgb_occ.deploy(
    initial_instance_count=1,
    instance_type="ml.t2.medium", 
    endpoint_name="sfu-occupancy-predictor"
)

# Deploy departure model
predictor_dep = xgb_dep.deploy(
    initial_instance_count=1,
    instance_type="ml.t2.medium",
    endpoint_name="sfu-departure-predictor"
)

print("\n--- DEPLOYMENT COMPLETE ---")
print("Endpoint 1: sfu-occupancy-predictor")
print("Endpoint 2: sfu-departure-predictor")
# Out:
# Region: us-west-2
# Role: arn:aws:iam::718465053795:role/AmazonSageMakerExecutionRole
# Reading data from: s3://c732-sfu-parking-data-lake/processed/training_features/
# Data Loaded. Shape: (947898, 11)
# Data uploaded to S3 for training.
# Training Occupancy Model...
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-11-20-21-42-19-040
# 2025-11-20 21:42:22 Starting - Starting the training job...
# 2025-11-20 21:42:38 Starting - Preparing the instances for training...
# 2025-11-20 21:42:59 Downloading - Downloading input data...
# 2025-11-20 21:43:44 Downloading - Downloading the training image......
# 2025-11-20 21:44:45 Training - Training image download completed. Training in progress../miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-11-20 21:44:48.561 ip-10-0-243-235.us-west-2.compute.internal:6 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-11-20 21:44:48.594 ip-10-0-243-235.us-west-2.compute.internal:6 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-11-20:21:44:49:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-11-20:21:44:49:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-11-20:21:44:49:INFO] No GPUs detected (normal if no gpus installed)
# [2025-11-20:21:44:49:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-11-20:21:44:49:INFO] Determined 0 GPU(s) available on the instance.
# [2025-11-20:21:44:49:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:44:49:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:44:49:INFO] files path: /opt/ml/input/data/train
# [2025-11-20:21:44:49:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:44:49:INFO] files path: /opt/ml/input/data/validation
# [2025-11-20:21:44:49:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:44:49:INFO] Single node training.
# [2025-11-20:21:44:49:INFO] Train matrix has 758318 rows and 16 columns
# [2025-11-20:21:44:49:INFO] Validation matrix has 189580 rows
# [2025-11-20 21:44:49.855 ip-10-0-243-235.us-west-2.compute.internal:6 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-11-20 21:44:49.855 ip-10-0-243-235.us-west-2.compute.internal:6 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-11-20 21:44:49.856 ip-10-0-243-235.us-west-2.compute.internal:6 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-11-20 21:44:49.856 ip-10-0-243-235.us-west-2.compute.internal:6 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-11-20:21:44:49:INFO] Debug hook created from config
# [2025-11-20 21:44:50.762 ip-10-0-243-235.us-west-2.compute.internal:6 INFO hook.py:427] Monitoring the collections: metrics
# [2025-11-20 21:44:50.766 ip-10-0-243-235.us-west-2.compute.internal:6 INFO hook.py:491] Hook is writing from the hook with pid: 6
# [0]#011train-rmse:224.70746#011validation-rmse:226.25207
# [1]#011train-rmse:180.37982#011validation-rmse:181.67366
# [2]#011train-rmse:144.97453#011validation-rmse:146.08614
# [3]#011train-rmse:116.77409#011validation-rmse:117.75108
# [4]#011train-rmse:94.31223#011validation-rmse:95.18007
# [5]#011train-rmse:76.52480#011validation-rmse:77.30685
# [6]#011train-rmse:62.46392#011validation-rmse:63.18256
# [7]#011train-rmse:51.44312#011validation-rmse:52.11633
# [8]#011train-rmse:42.85052#011validation-rmse:43.47602
# [9]#011train-rmse:36.05980#011validation-rmse:36.66590
# [10]#011train-rmse:31.02082#011validation-rmse:31.61200
# [11]#011train-rmse:27.17108#011validation-rmse:27.77744
# [12]#011train-rmse:24.37901#011validation-rmse:24.99176
# [13]#011train-rmse:22.27785#011validation-rmse:22.91176
# [14]#011train-rmse:20.68672#011validation-rmse:21.33321
# [15]#011train-rmse:19.57250#011validation-rmse:20.23010
# [16]#011train-rmse:18.83397#011validation-rmse:19.48798
# [17]#011train-rmse:18.20501#011validation-rmse:18.85882
# [18]#011train-rmse:17.81422#011validation-rmse:18.46395
# [19]#011train-rmse:17.38267#011validation-rmse:18.00766
# [20]#011train-rmse:16.99551#011validation-rmse:17.62212
# [21]#011train-rmse:16.74975#011validation-rmse:17.38086
# [22]#011train-rmse:16.58358#011validation-rmse:17.21469
# [23]#011train-rmse:16.30244#011validation-rmse:16.92259
# [24]#011train-rmse:16.17168#011validation-rmse:16.79704
# [25]#011train-rmse:16.01070#011validation-rmse:16.63133
# [26]#011train-rmse:15.92888#011validation-rmse:16.54210
# [27]#011train-rmse:15.82566#011validation-rmse:16.43648
# [28]#011train-rmse:15.63060#011validation-rmse:16.24187
# [29]#011train-rmse:15.55685#011validation-rmse:16.16813
# [30]#011train-rmse:15.51238#011validation-rmse:16.12570
# [31]#011train-rmse:15.43904#011validation-rmse:16.04734
# [32]#011train-rmse:15.38600#011validation-rmse:15.99542
# [33]#011train-rmse:15.35993#011validation-rmse:15.96823
# [34]#011train-rmse:15.30329#011validation-rmse:15.91239
# [35]#011train-rmse:15.22838#011validation-rmse:15.83546
# [36]#011train-rmse:15.18716#011validation-rmse:15.79310
# [37]#011train-rmse:15.16822#011validation-rmse:15.77741
# [38]#011train-rmse:15.04776#011validation-rmse:15.63494
# [39]#011train-rmse:15.03596#011validation-rmse:15.62279
# [40]#011train-rmse:14.95810#011validation-rmse:15.54604
# [41]#011train-rmse:14.93227#011validation-rmse:15.52214
# [42]#011train-rmse:14.89548#011validation-rmse:15.49127
# [43]#011train-rmse:14.83864#011validation-rmse:15.43662
# [44]#011train-rmse:14.80161#011validation-rmse:15.39533
# [45]#011train-rmse:14.71808#011validation-rmse:15.30645
# [46]#011train-rmse:14.68780#011validation-rmse:15.27055
# [47]#011train-rmse:14.65689#011validation-rmse:15.23892
# [48]#011train-rmse:14.61878#011validation-rmse:15.20215
# [49]#011train-rmse:14.54911#011validation-rmse:15.13431
# [50]#011train-rmse:14.52045#011validation-rmse:15.10353
# [51]#011train-rmse:14.48295#011validation-rmse:15.07316
# [52]#011train-rmse:14.43430#011validation-rmse:15.02632
# [53]#011train-rmse:14.41277#011validation-rmse:15.01052
# [54]#011train-rmse:14.37357#011validation-rmse:14.97476
# [55]#011train-rmse:14.34699#011validation-rmse:14.94624
# [56]#011train-rmse:14.32863#011validation-rmse:14.92128
# [57]#011train-rmse:14.31118#011validation-rmse:14.89944
# [58]#011train-rmse:14.28875#011validation-rmse:14.88424
# [59]#011train-rmse:14.24386#011validation-rmse:14.83749
# [60]#011train-rmse:14.22120#011validation-rmse:14.81726
# [61]#011train-rmse:14.20813#011validation-rmse:14.80497
# [62]#011train-rmse:14.18246#011validation-rmse:14.78282
# [63]#011train-rmse:14.16221#011validation-rmse:14.76693
# [64]#011train-rmse:14.11717#011validation-rmse:14.71138
# [65]#011train-rmse:14.07948#011validation-rmse:14.67340
# [66]#011train-rmse:14.05218#011validation-rmse:14.64724
# [67]#011train-rmse:14.03880#011validation-rmse:14.64161
# [68]#011train-rmse:14.02585#011validation-rmse:14.62858
# [69]#011train-rmse:13.99746#011validation-rmse:14.60157
# [70]#011train-rmse:13.98334#011validation-rmse:14.59061
# [71]#011train-rmse:13.97664#011validation-rmse:14.58584
# [72]#011train-rmse:13.96377#011validation-rmse:14.57346
# [73]#011train-rmse:13.91016#011validation-rmse:14.51861
# [74]#011train-rmse:13.89118#011validation-rmse:14.50108
# [75]#011train-rmse:13.88191#011validation-rmse:14.49440
# [76]#011train-rmse:13.87220#011validation-rmse:14.48652
# [77]#011train-rmse:13.86472#011validation-rmse:14.47916
# [78]#011train-rmse:13.85575#011validation-rmse:14.47219
# [79]#011train-rmse:13.84282#011validation-rmse:14.46423
# [80]#011train-rmse:13.83817#011validation-rmse:14.45754
# [81]#011train-rmse:13.81962#011validation-rmse:14.44008
# [82]#011train-rmse:13.81343#011validation-rmse:14.43536
# [83]#011train-rmse:13.79954#011validation-rmse:14.42048
# [84]#011train-rmse:13.76954#011validation-rmse:14.38571
# [85]#011train-rmse:13.75509#011validation-rmse:14.37186
# [86]#011train-rmse:13.74354#011validation-rmse:14.36040
# [87]#011train-rmse:13.74053#011validation-rmse:14.35834
# [88]#011train-rmse:13.73154#011validation-rmse:14.35340
# [89]#011train-rmse:13.70799#011validation-rmse:14.32408
# [90]#011train-rmse:13.69799#011validation-rmse:14.31760
# [91]#011train-rmse:13.67950#011validation-rmse:14.29931
# [92]#011train-rmse:13.66903#011validation-rmse:14.28951
# [93]#011train-rmse:13.65221#011validation-rmse:14.27464
# [94]#011train-rmse:13.64227#011validation-rmse:14.26511
# [95]#011train-rmse:13.63215#011validation-rmse:14.25669
# [96]#011train-rmse:13.61253#011validation-rmse:14.24022
# [97]#011train-rmse:13.59281#011validation-rmse:14.22065
# [98]#011train-rmse:13.58596#011validation-rmse:14.21587
# [99]#011train-rmse:13.57852#011validation-rmse:14.20863
#
# 2025-11-20 21:45:46 Uploading - Uploading generated training model
# 2025-11-20 21:45:59 Completed - Training job completed
# Training seconds: 180
# Billable seconds: 180
# Training Departure Model...
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-11-20-21-47-01-560
# 2025-11-20 21:47:06 Starting - Starting the training job...
# 2025-11-20 21:47:21 Starting - Preparing the instances for training...
# 2025-11-20 21:47:43 Downloading - Downloading input data...
# 2025-11-20 21:48:34 Downloading - Downloading the training image......
# 2025-11-20 21:49:35 Training - Training image download completed. Training in progress.../miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-11-20 21:49:37.222 ip-10-0-104-37.us-west-2.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-11-20 21:49:37.244 ip-10-0-104-37.us-west-2.compute.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-11-20:21:49:37:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-11-20:21:49:37:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-11-20:21:49:37:INFO] No GPUs detected (normal if no gpus installed)
# [2025-11-20:21:49:37:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-11-20:21:49:37:INFO] Determined 0 GPU(s) available on the instance.
# [2025-11-20:21:49:37:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:49:37:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:49:37:INFO] files path: /opt/ml/input/data/train
# [2025-11-20:21:49:37:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:49:38:INFO] files path: /opt/ml/input/data/validation
# [2025-11-20:21:49:38:INFO] Determined delimiter of CSV input is ','
# [2025-11-20:21:49:38:INFO] Single node training.
# [2025-11-20:21:49:38:INFO] Train matrix has 758318 rows and 16 columns
# [2025-11-20:21:49:38:INFO] Validation matrix has 189580 rows
# [2025-11-20 21:49:38.562 ip-10-0-104-37.us-west-2.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-11-20 21:49:38.563 ip-10-0-104-37.us-west-2.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-11-20 21:49:38.564 ip-10-0-104-37.us-west-2.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-11-20 21:49:38.564 ip-10-0-104-37.us-west-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-11-20:21:49:38:INFO] Debug hook created from config
# [2025-11-20 21:49:39.552 ip-10-0-104-37.us-west-2.compute.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2025-11-20 21:49:39.554 ip-10-0-104-37.us-west-2.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-rmse:15.12879#011validation-rmse:15.19837
# [1]#011train-rmse:12.10643#011validation-rmse:12.16373
# [2]#011train-rmse:9.69050#011validation-rmse:9.73655
# [3]#011train-rmse:7.75548#011validation-rmse:7.79215
# [4]#011train-rmse:6.20684#011validation-rmse:6.23620
# [5]#011train-rmse:4.96847#011validation-rmse:4.99155
# [6]#011train-rmse:3.97655#011validation-rmse:3.99516
# [7]#011train-rmse:3.18268#011validation-rmse:3.19739
# [8]#011train-rmse:2.54787#011validation-rmse:2.55930
# [9]#011train-rmse:2.03926#011validation-rmse:2.04785
# [10]#011train-rmse:1.63249#011validation-rmse:1.63884
# [11]#011train-rmse:1.30698#011validation-rmse:1.31197
# [12]#011train-rmse:1.04647#011validation-rmse:1.05006
# [13]#011train-rmse:0.83799#011validation-rmse:0.84072
# [14]#011train-rmse:0.67128#011validation-rmse:0.67315
# [15]#011train-rmse:0.53792#011validation-rmse:0.53931
# [16]#011train-rmse:0.43122#011validation-rmse:0.43233
# [17]#011train-rmse:0.34601#011validation-rmse:0.34677
# [18]#011train-rmse:0.27802#011validation-rmse:0.27831
# [19]#011train-rmse:0.22394#011validation-rmse:0.22390
# [20]#011train-rmse:0.18071#011validation-rmse:0.18056
# [21]#011train-rmse:0.14642#011validation-rmse:0.14616
# [22]#011train-rmse:0.11939#011validation-rmse:0.11901
# [23]#011train-rmse:0.09805#011validation-rmse:0.09759
# [24]#011train-rmse:0.08148#011validation-rmse:0.08088
# [25]#011train-rmse:0.06876#011validation-rmse:0.06794
# [26]#011train-rmse:0.05924#011validation-rmse:0.05821
# [27]#011train-rmse:0.05181#011validation-rmse:0.05077
# [28]#011train-rmse:0.04612#011validation-rmse:0.04509
# [29]#011train-rmse:0.04198#011validation-rmse:0.04081
# [30]#011train-rmse:0.03894#011validation-rmse:0.03765
# [31]#011train-rmse:0.03604#011validation-rmse:0.03494
# [32]#011train-rmse:0.03455#011validation-rmse:0.03350
# [33]#011train-rmse:0.03349#011validation-rmse:0.03246
# [34]#011train-rmse:0.03213#011validation-rmse:0.03119
# [35]#011train-rmse:0.03141#011validation-rmse:0.03043
# [36]#011train-rmse:0.03006#011validation-rmse:0.02882
# [37]#011train-rmse:0.02936#011validation-rmse:0.02808
# [38]#011train-rmse:0.02919#011validation-rmse:0.02784
# [39]#011train-rmse:0.02801#011validation-rmse:0.02648
# [40]#011train-rmse:0.02796#011validation-rmse:0.02643
# [41]#011train-rmse:0.02750#011validation-rmse:0.02620
# [42]#011train-rmse:0.02742#011validation-rmse:0.02611
# [43]#011train-rmse:0.02716#011validation-rmse:0.02612
# [44]#011train-rmse:0.02680#011validation-rmse:0.02587
# [45]#011train-rmse:0.02681#011validation-rmse:0.02581
# [46]#011train-rmse:0.02614#011validation-rmse:0.02494
# [47]#011train-rmse:0.02553#011validation-rmse:0.02423
# [48]#011train-rmse:0.02521#011validation-rmse:0.02394
# [49]#011train-rmse:0.02489#011validation-rmse:0.02364
# [50]#011train-rmse:0.02470#011validation-rmse:0.02354
# [51]#011train-rmse:0.02455#011validation-rmse:0.02354
# [52]#011train-rmse:0.02444#011validation-rmse:0.02335
# [53]#011train-rmse:0.02387#011validation-rmse:0.02278
# [54]#011train-rmse:0.02374#011validation-rmse:0.02273
# [55]#011train-rmse:0.02357#011validation-rmse:0.02242
# [56]#011train-rmse:0.02357#011validation-rmse:0.02242
# [57]#011train-rmse:0.02357#011validation-rmse:0.02242
# [58]#011train-rmse:0.02335#011validation-rmse:0.02230
# [59]#011train-rmse:0.02337#011validation-rmse:0.02224
# [60]#011train-rmse:0.02323#011validation-rmse:0.02220
# [61]#011train-rmse:0.02290#011validation-rmse:0.02192
# [62]#011train-rmse:0.02282#011validation-rmse:0.02192
# [63]#011train-rmse:0.02282#011validation-rmse:0.02192
# [64]#011train-rmse:0.02260#011validation-rmse:0.02148
# [65]#011train-rmse:0.02241#011validation-rmse:0.02133
# [66]#011train-rmse:0.02241#011validation-rmse:0.02133
# [67]#011train-rmse:0.02241#011validation-rmse:0.02133
# [68]#011train-rmse:0.02203#011validation-rmse:0.02091
# [69]#011train-rmse:0.02203#011validation-rmse:0.02091
# [70]#011train-rmse:0.02192#011validation-rmse:0.02081
# [71]#011train-rmse:0.02192#011validation-rmse:0.02073
# [72]#011train-rmse:0.02193#011validation-rmse:0.02066
# [73]#011train-rmse:0.02193#011validation-rmse:0.02066
# [74]#011train-rmse:0.02193#011validation-rmse:0.02066
# [75]#011train-rmse:0.02193#011validation-rmse:0.02066
# [76]#011train-rmse:0.02193#011validation-rmse:0.02066
# [77]#011train-rmse:0.02189#011validation-rmse:0.02086
# [78]#011train-rmse:0.02143#011validation-rmse:0.02038
# [79]#011train-rmse:0.02143#011validation-rmse:0.02038
# [80]#011train-rmse:0.02143#011validation-rmse:0.02038
# [81]#011train-rmse:0.02143#011validation-rmse:0.02038
# [82]#011train-rmse:0.02127#011validation-rmse:0.02017
# [83]#011train-rmse:0.02111#011validation-rmse:0.02013
# [84]#011train-rmse:0.02111#011validation-rmse:0.02013
# [85]#011train-rmse:0.02111#011validation-rmse:0.02004
# [86]#011train-rmse:0.02111#011validation-rmse:0.02004
# [87]#011train-rmse:0.02111#011validation-rmse:0.02004
# [88]#011train-rmse:0.02111#011validation-rmse:0.02004
# [89]#011train-rmse:0.02111#011validation-rmse:0.02004
# [90]#011train-rmse:0.02093#011validation-rmse:0.01993
# [91]#011train-rmse:0.02093#011validation-rmse:0.01993
# [92]#011train-rmse:0.02093#011validation-rmse:0.01993
# [93]#011train-rmse:0.02093#011validation-rmse:0.01993
# [94]#011train-rmse:0.02094#011validation-rmse:0.01985
# [95]#011train-rmse:0.02094#011validation-rmse:0.01985
# [96]#011train-rmse:0.02079#011validation-rmse:0.01981
# [97]#011train-rmse:0.02082#011validation-rmse:0.01973
# [98]#011train-rmse:0.02082#011validation-rmse:0.01973
# [99]#011train-rmse:0.02082#011validation-rmse:0.01973
#
# 2025-11-20 21:50:43 Uploading - Uploading generated training model
# 2025-11-20 21:50:43 Completed - Training job completed
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2025-11-20-21-51-13-641
# Training seconds: 180
# Billable seconds: 180
# Deploying Endpoints...
# INFO:sagemaker:Creating endpoint-config with name sfu-occupancy-predictor
# INFO:sagemaker:Creating endpoint with name sfu-occupancy-predictor
# ------!
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2025-11-20-21-54-45-872
# INFO:sagemaker:Creating endpoint-config with name sfu-departure-predictor
# INFO:sagemaker:Creating endpoint with name sfu-departure-predictor
# ---------!
# --- DEPLOYMENT COMPLETE ---
# Endpoint 1: sfu-occupancy-predictor
# Endpoint 2: sfu-departure-predictor
