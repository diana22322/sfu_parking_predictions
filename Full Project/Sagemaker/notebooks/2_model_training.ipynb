# %%
import sagemaker
import boto3
import pandas as pd
import numpy as np
from sagemaker import get_execution_role
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost.estimator import XGBoost
from sklearn.model_selection import train_test_split

# Configuration
role = get_execution_role()
session = sagemaker.Session()
region = boto3.Session().region_name
bucket = "c732-sfu-parking-data-lake" 
prefix = "sagemaker/sfu-parking"

# input path 
training_data_s3 = f"s3://{bucket}/processed/training_features/"

print(f"Region: {region}")
print(f"Role: {role}")
print(f"Reading data from: {training_data_s3}")

# load data
df = pd.read_parquet(training_data_s3)
print(f"Data Loaded. Shape: {df.shape}")

# drop non-feature columns for training (keep lot_id/campus but encode them)
# One-Hot Encode categorical variables
df_encoded = pd.get_dummies(df, columns=['lot_id', 'campus'])

# Define features (X) and labels (Y)
# drop target columns and identifiers not needed for X
features = df_encoded.drop(['occupancy_plus_15m', 'departures_in_15m', 'timestamp', 'date'], axis=1, errors='ignore')

# targets
label_occupancy = df['occupancy_plus_15m']
label_departure = df['departures_in_15m']

# split Data (80% training, 20% validation)
X_train, X_val, y_occ_train, y_occ_val, y_dep_train, y_dep_val = train_test_split(
    features, label_occupancy, label_departure, test_size=0.2, random_state=42
)

# Model training using XGBOOST 
# XGBoost in SageMaker expects CSV data in S3 with no headers
# first column = target label, remaining columns = features
def upload_to_s3(x, y, name):
    # combine label + features
    dataset = pd.concat([y, x], axis=1)
    filename = f"{name}.csv"
    dataset.to_csv(filename, header=False, index=False)
    
    return session.upload_data(filename, bucket=bucket, key_prefix=f"{prefix}/input/{name}")

# upload occupancy data
train_occ_uri = upload_to_s3(X_train, y_occ_train, 'train_occupancy')
val_occ_uri = upload_to_s3(X_val, y_occ_val, 'val_occupancy')

# upload departure data
train_dep_uri = upload_to_s3(X_train, y_dep_train, 'train_departure')
val_dep_uri = upload_to_s3(X_val, y_dep_val, 'val_departure')

print("Data uploaded to S3 for training.")

# Training 2 models
# Retrieve XGBoost container image
xgboost_container = sagemaker.image_uris.retrieve("xgboost", region, "1.5-1")

# Standard hyperparameters for both models (changed objective below)
base_hyperparams = {
    "max_depth": "5",
    "eta": "0.2",
    "gamma": "4",
    "min_child_weight": "6",
    "subsample": "0.8",
    "num_round": "100"
}

# Hyperparameters for Occupancy (standard regression for continuous-like data)
hyperparams_occ = base_hyperparams.copy()
hyperparams_occ["objective"] = "reg:squarederror"

# Hyperparameters for Departure (Poisson regression for count data)
hyperparams_dep = base_hyperparams.copy()
hyperparams_dep["objective"] = "count:poisson" 

# Train model A: occupancy predictor 
print("Training Occupancy Model...")
xgb_occ = sagemaker.estimator.Estimator(
    image_uri=xgboost_container,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=f"s3://{bucket}/{prefix}/output/occupancy",
    sagemaker_session=session
)
xgb_occ.set_hyperparameters(**hyperparams_occ)
xgb_occ.fit({'train': TrainingInput(train_occ_uri, content_type='csv'), 
             'validation': TrainingInput(val_occ_uri, content_type='csv')})

# Train model B: departure predictor
print("Training Departure Model...")
xgb_dep = sagemaker.estimator.Estimator(
    image_uri=xgboost_container,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=f"s3://{bucket}/{prefix}/output/departure",
    sagemaker_session=session
)
xgb_dep.set_hyperparameters(**hyperparams_dep) # Using the new Poisson objective
xgb_dep.fit({'train': TrainingInput(train_dep_uri, content_type='csv'), 
             'validation': TrainingInput(val_dep_uri, content_type='csv')})

print("Deploying Endpoints...")

# Deploy occupancy model
predictor_occ = xgb_occ.deploy(
    initial_instance_count=1,
    instance_type="ml.t2.medium", 
    endpoint_name="sfu-occupancy-predictor"
)

# Deploy departure model
predictor_dep = xgb_dep.deploy(
    initial_instance_count=1,
    instance_type="ml.t2.medium",
    endpoint_name="sfu-departure-predictor"
)

print("\n--- DEPLOYMENT COMPLETE ---")
print("Endpoint 1: sfu-occupancy-predictor")
print("Endpoint 2: sfu-departure-predictor")
# Out:
# Region: us-west-2
# Role: arn:aws:iam::718465053795:role/AmazonSageMakerExecutionRole
# Reading data from: s3://c732-sfu-parking-data-lake/processed/training_features/
# Data Loaded. Shape: (947898, 11)
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-11-24-22-29-52-432
# Data uploaded to S3 for training.
# Training Occupancy Model...
# 2025-11-24 22:29:54 Starting - Starting the training job...
# 2025-11-24 22:30:10 Starting - Preparing the instances for training...
# 2025-11-24 22:30:32 Downloading - Downloading input data...
# 2025-11-24 22:31:17 Downloading - Downloading the training image......
# 2025-11-24 22:32:13 Training - Training image download completed. Training in progress./miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-11-24 22:32:14.816 ip-10-0-167-33.us-west-2.compute.internal:8 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-11-24 22:32:14.840 ip-10-0-167-33.us-west-2.compute.internal:8 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-11-24:22:32:15:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-11-24:22:32:15:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2025-11-24:22:32:15:INFO] No GPUs detected (normal if no gpus installed)
# [2025-11-24:22:32:15:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-11-24:22:32:15:INFO] Determined 0 GPU(s) available on the instance.
# [2025-11-24:22:32:15:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:32:15:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:32:15:INFO] files path: /opt/ml/input/data/train
# [2025-11-24:22:32:15:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:32:15:INFO] files path: /opt/ml/input/data/validation
# [2025-11-24:22:32:15:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:32:16:INFO] Single node training.
# [2025-11-24:22:32:16:INFO] Train matrix has 758318 rows and 15 columns
# [2025-11-24:22:32:16:INFO] Validation matrix has 189580 rows
# [2025-11-24 22:32:16.118 ip-10-0-167-33.us-west-2.compute.internal:8 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-11-24 22:32:16.118 ip-10-0-167-33.us-west-2.compute.internal:8 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-11-24 22:32:16.119 ip-10-0-167-33.us-west-2.compute.internal:8 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-11-24 22:32:16.119 ip-10-0-167-33.us-west-2.compute.internal:8 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-11-24:22:32:16:INFO] Debug hook created from config
# [0]#011train-rmse:224.70985#011validation-rmse:226.26225
# [2025-11-24 22:32:16.965 ip-10-0-167-33.us-west-2.compute.internal:8 INFO hook.py:427] Monitoring the collections: metrics
# [2025-11-24 22:32:16.968 ip-10-0-167-33.us-west-2.compute.internal:8 INFO hook.py:491] Hook is writing from the hook with pid: 8
# [1]#011train-rmse:180.38707#011validation-rmse:181.68520
# [2]#011train-rmse:144.98996#011validation-rmse:146.11848
# [3]#011train-rmse:116.80065#011validation-rmse:117.78714
# [4]#011train-rmse:94.35256#011validation-rmse:95.22600
# [5]#011train-rmse:76.59050#011validation-rmse:77.38350
# [6]#011train-rmse:62.58239#011validation-rmse:63.30766
# [7]#011train-rmse:51.63005#011validation-rmse:52.31495
# [8]#011train-rmse:43.11696#011validation-rmse:43.77095
# [9]#011train-rmse:36.49168#011validation-rmse:37.12152
# [10]#011train-rmse:31.41150#011validation-rmse:32.03279
# [11]#011train-rmse:27.64101#011validation-rmse:28.26998
# [12]#011train-rmse:24.86860#011validation-rmse:25.50840
# [13]#011train-rmse:22.86475#011validation-rmse:23.49674
# [14]#011train-rmse:21.43466#011validation-rmse:22.07996
# [15]#011train-rmse:20.39279#011validation-rmse:21.04727
# [16]#011train-rmse:19.62714#011validation-rmse:20.28969
# [17]#011train-rmse:19.08523#011validation-rmse:19.74291
# [18]#011train-rmse:18.71605#011validation-rmse:19.36463
# [19]#011train-rmse:18.38852#011validation-rmse:19.03682
# [20]#011train-rmse:18.15539#011validation-rmse:18.80745
# [21]#011train-rmse:17.93004#011validation-rmse:18.58781
# [22]#011train-rmse:17.79157#011validation-rmse:18.44384
# [23]#011train-rmse:17.69429#011validation-rmse:18.34227
# [24]#011train-rmse:17.61562#011validation-rmse:18.26450
# [25]#011train-rmse:17.54744#011validation-rmse:18.19022
# [26]#011train-rmse:17.44769#011validation-rmse:18.08813
# [27]#011train-rmse:17.40848#011validation-rmse:18.04491
# [28]#011train-rmse:17.34568#011validation-rmse:17.97928
# [29]#011train-rmse:17.30407#011validation-rmse:17.93629
# [30]#011train-rmse:17.28091#011validation-rmse:17.92289
# [31]#011train-rmse:17.23455#011validation-rmse:17.88524
# [32]#011train-rmse:17.20382#011validation-rmse:17.85089
# [33]#011train-rmse:17.16034#011validation-rmse:17.80082
# [34]#011train-rmse:17.13103#011validation-rmse:17.78167
# [35]#011train-rmse:17.07287#011validation-rmse:17.73203
# [36]#011train-rmse:17.01146#011validation-rmse:17.67895
# [37]#011train-rmse:16.98474#011validation-rmse:17.65977
# [38]#011train-rmse:16.95720#011validation-rmse:17.63917
# [39]#011train-rmse:16.94309#011validation-rmse:17.62550
# [40]#011train-rmse:16.91796#011validation-rmse:17.60094
# [41]#011train-rmse:16.87201#011validation-rmse:17.56433
# [42]#011train-rmse:16.83376#011validation-rmse:17.52493
# [43]#011train-rmse:16.81833#011validation-rmse:17.51992
# [44]#011train-rmse:16.80717#011validation-rmse:17.51634
# [45]#011train-rmse:16.73713#011validation-rmse:17.42892
# [46]#011train-rmse:16.69081#011validation-rmse:17.40200
# [47]#011train-rmse:16.67947#011validation-rmse:17.38824
# [48]#011train-rmse:16.65176#011validation-rmse:17.35696
# [49]#011train-rmse:16.62488#011validation-rmse:17.32822
# [50]#011train-rmse:16.59337#011validation-rmse:17.29796
# [51]#011train-rmse:16.57021#011validation-rmse:17.27868
# [52]#011train-rmse:16.52668#011validation-rmse:17.23246
# [53]#011train-rmse:16.51530#011validation-rmse:17.22378
# [54]#011train-rmse:16.48661#011validation-rmse:17.19638
# [55]#011train-rmse:16.46078#011validation-rmse:17.18071
# [56]#011train-rmse:16.44995#011validation-rmse:17.17057
# [57]#011train-rmse:16.42962#011validation-rmse:17.15052
# [58]#011train-rmse:16.42239#011validation-rmse:17.14778
# [59]#011train-rmse:16.40078#011validation-rmse:17.12756
# [60]#011train-rmse:16.38632#011validation-rmse:17.11811
# [61]#011train-rmse:16.37279#011validation-rmse:17.10706
# [62]#011train-rmse:16.32428#011validation-rmse:17.05334
# [63]#011train-rmse:16.30818#011validation-rmse:17.03422
# [64]#011train-rmse:16.29499#011validation-rmse:17.02836
# [65]#011train-rmse:16.27851#011validation-rmse:17.01522
# [66]#011train-rmse:16.27140#011validation-rmse:17.01281
# [67]#011train-rmse:16.26621#011validation-rmse:17.00997
# [68]#011train-rmse:16.25517#011validation-rmse:17.00164
# [69]#011train-rmse:16.23760#011validation-rmse:16.98683
# [70]#011train-rmse:16.22502#011validation-rmse:16.97793
# [71]#011train-rmse:16.22054#011validation-rmse:16.97903
# [72]#011train-rmse:16.21195#011validation-rmse:16.97077
# [73]#011train-rmse:16.20585#011validation-rmse:16.96841
# [74]#011train-rmse:16.18490#011validation-rmse:16.94979
# [75]#011train-rmse:16.17042#011validation-rmse:16.94052
# [76]#011train-rmse:16.16607#011validation-rmse:16.93820
# [77]#011train-rmse:16.13272#011validation-rmse:16.90652
# [78]#011train-rmse:16.12821#011validation-rmse:16.90312
# [79]#011train-rmse:16.11606#011validation-rmse:16.88849
# [80]#011train-rmse:16.10414#011validation-rmse:16.88184
# [81]#011train-rmse:16.08693#011validation-rmse:16.86549
# [82]#011train-rmse:16.06826#011validation-rmse:16.84898
# [83]#011train-rmse:16.06533#011validation-rmse:16.84700
# [84]#011train-rmse:16.06147#011validation-rmse:16.84614
# [85]#011train-rmse:16.04954#011validation-rmse:16.83460
# [86]#011train-rmse:16.02771#011validation-rmse:16.81445
# [87]#011train-rmse:16.02102#011validation-rmse:16.81361
# [88]#011train-rmse:16.01821#011validation-rmse:16.81137
# [89]#011train-rmse:16.00868#011validation-rmse:16.81154
# [90]#011train-rmse:15.99736#011validation-rmse:16.80176
# [91]#011train-rmse:15.98638#011validation-rmse:16.79707
# [92]#011train-rmse:15.98204#011validation-rmse:16.80107
# [93]#011train-rmse:15.97909#011validation-rmse:16.80229
# [94]#011train-rmse:15.97073#011validation-rmse:16.79765
# [95]#011train-rmse:15.96027#011validation-rmse:16.78843
# [96]#011train-rmse:15.95140#011validation-rmse:16.78233
# [97]#011train-rmse:15.94339#011validation-rmse:16.77575
# [98]#011train-rmse:15.94006#011validation-rmse:16.77882
# [99]#011train-rmse:15.92716#011validation-rmse:16.76576
#
# 2025-11-24 22:33:26 Uploading - Uploading generated training model
# 2025-11-24 22:33:26 Completed - Training job completed
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2025-11-24-22-33-39-976
# Training seconds: 175
# Billable seconds: 175
# Training Departure Model...
# 2025-11-24 22:33:42 Starting - Starting the training job...
# 2025-11-24 22:33:57 Starting - Preparing the instances for training...
# 2025-11-24 22:34:18 Downloading - Downloading input data...
# 2025-11-24 22:35:08 Downloading - Downloading the training image......
# 2025-11-24 22:35:59 Training - Training image download completed. Training in progress./miniconda3/lib/python3.8/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [2025-11-24 22:36:01.089 ip-10-0-155-188.us-west-2.compute.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2025-11-24 22:36:01.111 ip-10-0-155-188.us-west-2.compute.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2025-11-24:22:36:01:INFO] Imported framework sagemaker_xgboost_container.training
# [2025-11-24:22:36:01:INFO] Failed to parse hyperparameter objective value count:poisson to Json.
# Returning the value itself
# [2025-11-24:22:36:01:INFO] No GPUs detected (normal if no gpus installed)
# [2025-11-24:22:36:01:INFO] Running XGBoost Sagemaker in algorithm mode
# [2025-11-24:22:36:01:INFO] Determined 0 GPU(s) available on the instance.
# [2025-11-24:22:36:01:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:36:01:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:36:01:INFO] files path: /opt/ml/input/data/train
# [2025-11-24:22:36:01:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:36:02:INFO] files path: /opt/ml/input/data/validation
# [2025-11-24:22:36:02:INFO] Determined delimiter of CSV input is ','
# [2025-11-24:22:36:02:INFO] Single node training.
# [2025-11-24:22:36:02:INFO] Train matrix has 758318 rows and 15 columns
# [2025-11-24:22:36:02:INFO] Validation matrix has 189580 rows
# [2025-11-24 22:36:02.368 ip-10-0-155-188.us-west-2.compute.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2025-11-24 22:36:02.369 ip-10-0-155-188.us-west-2.compute.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2025-11-24 22:36:02.370 ip-10-0-155-188.us-west-2.compute.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2025-11-24 22:36:02.370 ip-10-0-155-188.us-west-2.compute.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2025-11-24:22:36:02:INFO] Debug hook created from config
# [2025-11-24 22:36:03.269 ip-10-0-155-188.us-west-2.compute.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2025-11-24 22:36:03.272 ip-10-0-155-188.us-west-2.compute.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-poisson-nloglik:22.84988#011validation-poisson-nloglik:22.91597
# [1]#011train-poisson-nloglik:21.93830#011validation-poisson-nloglik:21.95565
# [2]#011train-poisson-nloglik:20.99490#011validation-poisson-nloglik:21.03309
# [3]#011train-poisson-nloglik:20.08775#011validation-poisson-nloglik:20.11531
# [4]#011train-poisson-nloglik:19.17103#011validation-poisson-nloglik:19.17564
# [5]#011train-poisson-nloglik:18.27265#011validation-poisson-nloglik:18.26848
# [6]#011train-poisson-nloglik:17.26176#011validation-poisson-nloglik:17.38049
# [7]#011train-poisson-nloglik:16.38827#011validation-poisson-nloglik:16.49788
# [8]#011train-poisson-nloglik:15.52224#011validation-poisson-nloglik:15.60542
# [9]#011train-poisson-nloglik:14.64589#011validation-poisson-nloglik:14.71146
# [10]#011train-poisson-nloglik:13.79553#011validation-poisson-nloglik:13.85168
# [11]#011train-poisson-nloglik:12.95531#011validation-poisson-nloglik:12.99027
# [12]#011train-poisson-nloglik:12.13345#011validation-poisson-nloglik:12.15424
# [13]#011train-poisson-nloglik:11.24673#011validation-poisson-nloglik:11.33771
# [14]#011train-poisson-nloglik:10.44595#011validation-poisson-nloglik:10.53320
# [15]#011train-poisson-nloglik:9.67201#011validation-poisson-nloglik:9.74633
# [16]#011train-poisson-nloglik:8.90511#011validation-poisson-nloglik:8.96259
# [17]#011train-poisson-nloglik:8.17096#011validation-poisson-nloglik:8.22178
# [18]#011train-poisson-nloglik:7.46232#011validation-poisson-nloglik:7.50227
# [19]#011train-poisson-nloglik:6.79023#011validation-poisson-nloglik:6.82245
# [20]#011train-poisson-nloglik:6.12289#011validation-poisson-nloglik:6.17376
# [21]#011train-poisson-nloglik:5.50889#011validation-poisson-nloglik:5.56412
# [22]#011train-poisson-nloglik:4.95556#011validation-poisson-nloglik:5.00529
# [23]#011train-poisson-nloglik:4.44257#011validation-poisson-nloglik:4.48532
# [24]#011train-poisson-nloglik:3.96358#011validation-poisson-nloglik:3.99795
# [25]#011train-poisson-nloglik:3.52296#011validation-poisson-nloglik:3.55212
# [26]#011train-poisson-nloglik:3.12020#011validation-poisson-nloglik:3.14366
# [27]#011train-poisson-nloglik:2.75611#011validation-poisson-nloglik:2.77235
# [28]#011train-poisson-nloglik:2.42290#011validation-poisson-nloglik:2.43795
# [29]#011train-poisson-nloglik:2.13572#011validation-poisson-nloglik:2.14852
# [30]#011train-poisson-nloglik:1.89673#011validation-poisson-nloglik:1.90733
# [31]#011train-poisson-nloglik:1.70071#011validation-poisson-nloglik:1.70968
# [32]#011train-poisson-nloglik:1.53328#011validation-poisson-nloglik:1.54046
# [33]#011train-poisson-nloglik:1.40914#011validation-poisson-nloglik:1.41379
# [34]#011train-poisson-nloglik:1.31446#011validation-poisson-nloglik:1.31738
# [35]#011train-poisson-nloglik:1.24016#011validation-poisson-nloglik:1.24208
# [36]#011train-poisson-nloglik:1.18324#011validation-poisson-nloglik:1.18401
# [37]#011train-poisson-nloglik:1.13978#011validation-poisson-nloglik:1.13929
# [38]#011train-poisson-nloglik:1.10182#011validation-poisson-nloglik:1.10086
# [39]#011train-poisson-nloglik:1.07312#011validation-poisson-nloglik:1.07203
# [40]#011train-poisson-nloglik:1.04792#011validation-poisson-nloglik:1.04642
# [41]#011train-poisson-nloglik:1.02771#011validation-poisson-nloglik:1.02628
# [42]#011train-poisson-nloglik:1.01069#011validation-poisson-nloglik:1.00908
# [43]#011train-poisson-nloglik:0.99787#011validation-poisson-nloglik:0.99615
# [44]#011train-poisson-nloglik:0.98638#011validation-poisson-nloglik:0.98444
# [45]#011train-poisson-nloglik:0.97768#011validation-poisson-nloglik:0.97528
# [46]#011train-poisson-nloglik:0.96859#011validation-poisson-nloglik:0.96630
# [47]#011train-poisson-nloglik:0.96095#011validation-poisson-nloglik:0.95895
# [48]#011train-poisson-nloglik:0.95469#011validation-poisson-nloglik:0.95256
# [49]#011train-poisson-nloglik:0.94939#011validation-poisson-nloglik:0.94750
# [50]#011train-poisson-nloglik:0.94427#011validation-poisson-nloglik:0.94232
# [51]#011train-poisson-nloglik:0.93955#011validation-poisson-nloglik:0.93751
# [52]#011train-poisson-nloglik:0.93614#011validation-poisson-nloglik:0.93400
# [53]#011train-poisson-nloglik:0.93370#011validation-poisson-nloglik:0.93139
# [54]#011train-poisson-nloglik:0.93062#011validation-poisson-nloglik:0.92812
# [55]#011train-poisson-nloglik:0.92843#011validation-poisson-nloglik:0.92582
# [56]#011train-poisson-nloglik:0.92625#011validation-poisson-nloglik:0.92353
# [57]#011train-poisson-nloglik:0.92434#011validation-poisson-nloglik:0.92156
# [58]#011train-poisson-nloglik:0.92175#011validation-poisson-nloglik:0.91904
# [59]#011train-poisson-nloglik:0.91987#011validation-poisson-nloglik:0.91713
# [60]#011train-poisson-nloglik:0.91803#011validation-poisson-nloglik:0.91537
# [61]#011train-poisson-nloglik:0.91724#011validation-poisson-nloglik:0.91457
# [62]#011train-poisson-nloglik:0.91622#011validation-poisson-nloglik:0.91361
# [63]#011train-poisson-nloglik:0.91532#011validation-poisson-nloglik:0.91260
# [64]#011train-poisson-nloglik:0.91400#011validation-poisson-nloglik:0.91121
# [65]#011train-poisson-nloglik:0.91331#011validation-poisson-nloglik:0.91051
# [66]#011train-poisson-nloglik:0.91224#011validation-poisson-nloglik:0.90941
# [67]#011train-poisson-nloglik:0.91169#011validation-poisson-nloglik:0.90879
# [68]#011train-poisson-nloglik:0.91125#011validation-poisson-nloglik:0.90834
# [69]#011train-poisson-nloglik:0.91029#011validation-poisson-nloglik:0.90734
# [70]#011train-poisson-nloglik:0.90957#011validation-poisson-nloglik:0.90660
# [71]#011train-poisson-nloglik:0.90933#011validation-poisson-nloglik:0.90631
# [72]#011train-poisson-nloglik:0.90907#011validation-poisson-nloglik:0.90603
# [73]#011train-poisson-nloglik:0.90881#011validation-poisson-nloglik:0.90574
# [74]#011train-poisson-nloglik:0.90737#011validation-poisson-nloglik:0.90432
# [75]#011train-poisson-nloglik:0.90632#011validation-poisson-nloglik:0.90329
# [76]#011train-poisson-nloglik:0.90607#011validation-poisson-nloglik:0.90307
# [77]#011train-poisson-nloglik:0.90505#011validation-poisson-nloglik:0.90202
# [78]#011train-poisson-nloglik:0.90471#011validation-poisson-nloglik:0.90165
# [79]#011train-poisson-nloglik:0.90417#011validation-poisson-nloglik:0.90121
# [80]#011train-poisson-nloglik:0.90287#011validation-poisson-nloglik:0.90006
# [81]#011train-poisson-nloglik:0.90222#011validation-poisson-nloglik:0.89943
# [82]#011train-poisson-nloglik:0.90206#011validation-poisson-nloglik:0.89928
# [83]#011train-poisson-nloglik:0.90145#011validation-poisson-nloglik:0.89870
# [84]#011train-poisson-nloglik:0.90044#011validation-poisson-nloglik:0.89780
# [85]#011train-poisson-nloglik:0.89965#011validation-poisson-nloglik:0.89704
# [86]#011train-poisson-nloglik:0.89882#011validation-poisson-nloglik:0.89621
# [87]#011train-poisson-nloglik:0.89804#011validation-poisson-nloglik:0.89556
# [88]#011train-poisson-nloglik:0.89794#011validation-poisson-nloglik:0.89543
# [89]#011train-poisson-nloglik:0.89766#011validation-poisson-nloglik:0.89514
# [90]#011train-poisson-nloglik:0.89733#011validation-poisson-nloglik:0.89489
# [91]#011train-poisson-nloglik:0.89645#011validation-poisson-nloglik:0.89406
# [92]#011train-poisson-nloglik:0.89607#011validation-poisson-nloglik:0.89376
# [93]#011train-poisson-nloglik:0.89584#011validation-poisson-nloglik:0.89358
# [94]#011train-poisson-nloglik:0.89533#011validation-poisson-nloglik:0.89312
# [95]#011train-poisson-nloglik:0.89514#011validation-poisson-nloglik:0.89293
# [96]#011train-poisson-nloglik:0.89414#011validation-poisson-nloglik:0.89191
# [97]#011train-poisson-nloglik:0.89337#011validation-poisson-nloglik:0.89132
# [98]#011train-poisson-nloglik:0.89286#011validation-poisson-nloglik:0.89076
# [99]#011train-poisson-nloglik:0.89257#011validation-poisson-nloglik:0.89051
#
# 2025-11-24 22:37:04 Uploading - Uploading generated training model
# 2025-11-24 22:37:17 Completed - Training job completed
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2025-11-24-22-37-58-180
# Training seconds: 180
# Billable seconds: 180
# Deploying Endpoints...
# INFO:sagemaker:Creating endpoint-config with name sfu-occupancy-predictor
# INFO:sagemaker:Creating endpoint with name sfu-occupancy-predictor
# ----------!
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2025-11-24-22-43-30-558
# INFO:sagemaker:Creating endpoint-config with name sfu-departure-predictor
# INFO:sagemaker:Creating endpoint with name sfu-departure-predictor
# ----------!
# --- DEPLOYMENT COMPLETE ---
# Endpoint 1: sfu-occupancy-predictor
# Endpoint 2: sfu-departure-predictor
